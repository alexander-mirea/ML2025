# %% [markdown]
# # Линейная регрессия

# %% [markdown]
# Последовательность работы:
# 1. Постановка задачи
# 2. Сбор, анализ, подготовка данных
# 3. Обучение модели
# 4. Оценка модели

# %% [markdown]
# # Какие инструменты мы будем использовать
#
# Библиотеки питона, которые мы сегодня используем
#
# * pandas - стандартная библиотека для работы с табличными данными
# * sklearn - библиотека с метриками, методами предобработки данных, моделями машинного обучения и многим другим
# * matplotlib - самая популярная библиотека для рисования графиков на питоне
# * numpy — библиотека для работы с многомерными массивами

# %%
# импортируем библиотеки
import pandas as pd # библиотека для табличных данных
import numpy as np  # для числовых операций
import matplotlib.pyplot as plt # для графиков
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# # Постановка задачи
#
# ## Предсказать цену на жильё на основе имеющихся данных

# %% [markdown]
# https://www.kaggle.com/competitions/home-data-for-ml-course/overview

# %% [markdown]
# ## Загрузка набора данных

# %%
df = pd.read_csv('train.csv', sep=',')
df.head() # первые пять строк
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df[:5] # можно так, синтаксис не отличается от срезов
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
len(df)
# Out:
# 1460

# %%
df[df["SalePrice"]>600000] # фильтрация
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 898          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1169         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 691       1   2007        WD         Normal     755000
# 898       3   2010       New        Partial     611657
# 1169      7   2006        WD         Normal     625000
# 1182      7   2007        WD        Abnorml     745000
#
# [4 rows x 81 columns]

# %%
# не путать с where
df.where(df["SalePrice"]>200000)
# Out:
#           Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1.0        60.0       RL         65.0   8450.0   Pave   NaN      Reg
# 1        NaN         NaN      NaN          NaN      NaN    NaN   NaN      NaN
# 2        3.0        60.0       RL         68.0  11250.0   Pave   NaN      IR1
# 3        NaN         NaN      NaN          NaN      NaN    NaN   NaN      NaN
# 4        5.0        60.0       RL         84.0  14260.0   Pave   NaN      IR1
# ...      ...         ...      ...          ...      ...    ...   ...      ...
# 1455     NaN         NaN      NaN          NaN      NaN    NaN   NaN      NaN
# 1456  1457.0        20.0       RL         85.0  13175.0   Pave   NaN      Reg
# 1457  1458.0        70.0       RL         66.0   9042.0   Pave   NaN      Reg
# 1458     NaN         NaN      NaN          NaN      NaN    NaN   NaN      NaN
# 1459     NaN         NaN      NaN          NaN      NaN    NaN   NaN      NaN
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...      0.0    NaN    NaN         NaN     0.0
# 1            NaN       NaN  ...      NaN    NaN    NaN         NaN     NaN
# 2            Lvl    AllPub  ...      0.0    NaN    NaN         NaN     0.0
# 3            NaN       NaN  ...      NaN    NaN    NaN         NaN     NaN
# 4            Lvl    AllPub  ...      0.0    NaN    NaN         NaN     0.0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         NaN       NaN  ...      NaN    NaN    NaN         NaN     NaN
# 1456         Lvl    AllPub  ...      0.0    NaN  MnPrv         NaN     0.0
# 1457         Lvl    AllPub  ...      0.0    NaN  GdPrv        Shed  2500.0
# 1458         NaN       NaN  ...      NaN    NaN    NaN         NaN     NaN
# 1459         NaN       NaN  ...      NaN    NaN    NaN         NaN     NaN
#
#      MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       2.0  2008.0        WD         Normal   208500.0
# 1       NaN     NaN       NaN            NaN        NaN
# 2       9.0  2008.0        WD         Normal   223500.0
# 3       NaN     NaN       NaN            NaN        NaN
# 4      12.0  2008.0        WD         Normal   250000.0
# ...     ...     ...       ...            ...        ...
# 1455    NaN     NaN       NaN            NaN        NaN
# 1456    2.0  2010.0        WD         Normal   210000.0
# 1457    5.0  2010.0        WD         Normal   266500.0
# 1458    NaN     NaN       NaN            NaN        NaN
# 1459    NaN     NaN       NaN            NaN        NaN
#
# [1460 rows x 81 columns]

# %%
df['Neighborhood'].unique() #set(df['LotShape'].values)
# Out:
# array(['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst',
#        'NWAmes', 'OldTown', 'BrkSide', 'Sawyer', 'NridgHt', 'NAmes',
#        'SawyerW', 'IDOTRR', 'MeadowV', 'Edwards', 'Timber', 'Gilbert',
#        'StoneBr', 'ClearCr', 'NPkVill', 'Blmngtn', 'BrDale', 'SWISU',
#        'Blueste'], dtype=object)

# %%
df[df['Neighborhood'].isin(['Gilbert', 'Mitchel'])] # фильтрация
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 46      47          50       RL         48.0    12822   Pave   NaN      IR1
# 50      51          60       RL          NaN    13869   Pave   NaN      IR2
# 71      72          20       RL         69.0     7599   Pave   NaN      Reg
# 72      73          60       RL         74.0    10141   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1433  1434          60       RL         93.0    10261   Pave   NaN      IR1
# 1434  1435          20       RL         80.0    17400   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 5            Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 46           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 50           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 71           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 72           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1433         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1434         Low    AllPub  ...        0    NaN    NaN         NaN       0
# 1446         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1453         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 5        10   2009        WD         Normal     143000
# 46        8   2009        WD        Abnorml     239686
# 50        7   2007        WD         Normal     177000
# 71        6   2007        WD         Normal     129500
# 72       12   2009        WD         Normal     185000
# ...     ...    ...       ...            ...        ...
# 1433      5   2008        WD         Normal     186500
# 1434      5   2006        WD         Normal     160000
# 1446      4   2010        WD         Normal     157900
# 1453      7   2006        WD        Abnorml      84500
# 1455      8   2007        WD         Normal     175000
#
# [128 rows x 81 columns]

# %%
df[["Id","MSSubClass"]][:3] # проекция
# Out:
#    Id  MSSubClass
# 0   1          60
# 1   2          20
# 2   3          60

# %%
df.drop(['Id', 'MSSubClass'], axis=1).head()
# Out:
#   MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour Utilities  \
# 0       RL         65.0     8450   Pave   NaN      Reg         Lvl    AllPub
# 1       RL         80.0     9600   Pave   NaN      Reg         Lvl    AllPub
# 2       RL         68.0    11250   Pave   NaN      IR1         Lvl    AllPub
# 3       RL         60.0     9550   Pave   NaN      IR1         Lvl    AllPub
# 4       RL         84.0    14260   Pave   NaN      IR1         Lvl    AllPub
#
#   LotConfig LandSlope  ... PoolArea PoolQC Fence MiscFeature MiscVal  MoSold  \
# 0    Inside       Gtl  ...        0    NaN   NaN         NaN       0       2
# 1       FR2       Gtl  ...        0    NaN   NaN         NaN       0       5
# 2    Inside       Gtl  ...        0    NaN   NaN         NaN       0       9
# 3    Corner       Gtl  ...        0    NaN   NaN         NaN       0       2
# 4       FR2       Gtl  ...        0    NaN   NaN         NaN       0      12
#
#    YrSold  SaleType  SaleCondition SalePrice
# 0    2008        WD         Normal    208500
# 1    2007        WD         Normal    181500
# 2    2008        WD         Normal    223500
# 3    2006        WD        Abnorml    140000
# 4    2008        WD         Normal    250000
#
# [5 rows x 79 columns]

# %%
df.iloc[:3, 0:2] #получение строк по числовым индексам
# Out:
#    Id  MSSubClass
# 0   1          60
# 1   2          20
# 2   3          60

# %%
df.sort_values('SalePrice', ascending=False) # сортировка
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 803    804          60       RL        107.0    13891   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 30      31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 533    534          20       RL         50.0     5000   Pave   NaN      Reg
# 968    969          50       RM         50.0     5925   Pave   NaN      Reg
# 916    917          20  C (all)         50.0     9000   Pave   NaN      Reg
# 495    496          30  C (all)         60.0     7879   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
# 1169         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 898          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 803          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 30           Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 533          Low    AllPub  ...        0    NaN    NaN         NaN       0
# 968          Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 916          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 495          Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 691       1   2007        WD         Normal     755000
# 1182      7   2007        WD        Abnorml     745000
# 1169      7   2006        WD         Normal     625000
# 898       3   2010       New        Partial     611657
# 803       1   2009       New        Partial     582933
# ...     ...    ...       ...            ...        ...
# 30        7   2008        WD         Normal      40000
# 533       1   2007        WD         Normal      39300
# 968       5   2009        WD        Abnorml      37900
# 916      10   2006        WD        Abnorml      35311
# 495      11   2009        WD        Abnorml      34900
#
# [1460 rows x 81 columns]

# %%
df.groupby('MSZoning').count() # группировка
# Out:
#             Id  MSSubClass  LotFrontage  LotArea  Street  Alley  LotShape  \
# MSZoning
# C (all)     10          10           10       10      10      2        10
# FV          65          65           57       65      65     24        65
# RH          16          16           13       16      16      2        16
# RL        1151        1151          922     1151    1151     20      1151
# RM         218         218          199      218     218     43       218
#
#           LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# MSZoning                                     ...
# C (all)            10         10         10  ...        10       0      3
# FV                 65         65         65  ...        65       0      1
# RH                 16         16         16  ...        16       0      2
# RL               1151       1151       1151  ...      1151       7    229
# RM                218        218        218  ...       218       0     46
#
#           MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# MSZoning
# C (all)             2       10      10      10        10             10
# FV                  0       65      65      65        65             65
# RH                  0       16      16      16        16             16
# RL                 45     1151    1151    1151      1151           1151
# RM                  7      218     218     218       218            218
#
#           SalePrice
# MSZoning
# C (all)          10
# FV               65
# RH               16
# RL             1151
# RM              218
#
# [5 rows x 80 columns]

# %%
df.groupby(["MSZoning"]).agg({
  "LotArea": "sum",
  "Id": "count",
  "SalePrice": "max"
})#.reset_index()
# Out:
#            LotArea    Id  SalePrice
# MSZoning
# C (all)      95013    10     133900
# FV          431526    65     370878
# RH          118081    16     200000
# RL        13319158  1151     755000
# RM         1390791   218     475000

# %% [markdown]
# ## Исследовательский анализ данных

# %%
df.info() # просмотр типов переменных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     588 non-null    object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

# %%
df.isnull().sum() # проверка на пропущенные значения
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
miss = df.isnull().sum()
miss = miss[miss>0].sort_values(ascending=False)
miss
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# dtype: int64

# %%
df.describe() # статистические показатели
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
plt.scatter(df['GrLivArea'], df['SalePrice'])

plt.xlabel('Above grade (ground) living area square feet')
plt.ylabel('The property\'s sale price in dollars')
# Out:
# Text(0, 0.5, "The property's sale price in dollars")

# %%
corr_matrix = df[numerical_cols.tolist()].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, cmap='coolwarm', center=0)
plt.title('Correlation Matrix')
plt.show()

# %%
# построим график
plt.scatter(df['OverallQual'], df['SalePrice'])

plt.xlabel('Overall material and finish quality')
plt.ylabel('The property\'s sale price in dollars')
# Out:
# Text(0, 0.5, "The property's sale price in dollars")

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['SalePrice'], kde=True)
plt.title('Distribution of SalePrice')
plt.xlabel('SalePrice')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(np.log1p(df['SalePrice']), kde=True)
plt.title('Distribution of SalePrice')
plt.xlabel('SalePrice')
plt.show()

# %%
# берем признаки с наиболее высокой корреляцией с целевой переменной

X = df[['GrLivArea', 'OverallQual']]

y = df['SalePrice']

# %%
# разобьем данные на обучающую и тестовую выборку
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3) # размер тестовой выборки составит 30%

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# Линейная регрессия:
# * Хорошо работает, если зависимость между целевой переменной и признаками имеет линейный характер
# * Хорошо интерпретируется
# * Перед использованием лучше провести нормализацию данных, т.к масштаб влияет на веса

# %%
# импортируем линейную регрессию
from sklearn.linear_model import LinearRegression

# создадим модель класса LinearRegression
model = LinearRegression()

# обучим нашу модель
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Теперь сделаем предсказания с помощью метода **.predict(X)**. Заметьте, что в метод **.fit(X, y)** мы подавали матрицу с признаками и вектор с правильными ответами. В метод **.predict(X)** мы подаем только матрицу с признаками, потому что мы хотим сделать предсказание.

# %%
y_pred = model.predict(X_test)

print(y_pred)
# Out:
# [165785.55790761 205910.23767488 121712.66131775 351272.99104366
#  192273.59481859 145501.91710951 225551.36693152 162287.13793823
#  161894.51353744 202568.94501418 146694.18036044 212407.30333229
#  175431.20153746 116964.80564503 152691.47173652 115315.55051661
#  135956.22833592 264076.7689985  230941.7341457  221952.99210587
#  231698.59059199 143495.62495987 168584.29388311 185026.86773917
#  362817.7769426  113766.25024446 150442.48747049 240587.37777555
#  108026.04103333 122462.32273976 191816.60294111 156739.64341536
#  216805.31700808 327997.8995818  205110.59882474 217062.39917302
#  184477.1160297  136306.07033286 166585.19675775 276713.86329211
#  170833.27814913 158546.02585246 247584.2177143  222352.81153094
#  126910.31384368 229599.53861036 193273.14338127 128559.5689721
#  180378.96692272 123511.84873058 159438.4245346  171383.02985861
#  251632.38939315 175781.04353439 184534.28848211 296712.02956996
#  173881.9012653   39963.97893919  72042.2927769   62653.731312
#  249433.38255526 201512.22399909 114066.11481326 179679.28292884
#  109368.23656867 135556.40891085 176130.88553133 191623.88825285
#  108026.04103333 250832.75054301 244485.61717    181578.42519793
#  125418.18602394 114166.06966953 231841.32785211 117964.35420771
#  154690.56886187 295855.21826741 194915.20348541 248341.07416059
#  158688.76311259  90633.89604272 216305.54272674 125760.8329966
#  167934.58731737 122162.45817096 171782.84928368 138255.19003009
#  110217.85284695 114166.06966953 224801.70550951 180728.80891965
#  141753.60999946  84036.87552904 154947.65102682 133857.1763543
#  259728.73275085 144752.2556875  111767.1531191  177330.34380655
#  252032.20881822 132008.01151334 207509.51537516 261677.85244807
#  138205.21260195 142695.98610973 160787.81509421 129958.93695985
#  163986.37049479 138155.23517382 -44833.32655554 124161.55529632
#  111867.10797537 192266.39979432 232498.22944213 137805.39317688
#  212057.46133535 118963.90277039 142995.85067853 187133.11474507
#  176080.9081032  150442.48747049 121412.79674895 124761.28443392
#  114166.06966953 158139.01140311 297611.62327637 124111.57786818
#  240651.74525224 164136.30277919 211357.77734148 130358.75638492
#  185226.77745171 215905.72330167 261285.22804728 146994.04492925
#   92583.01573995 144295.26381002 111524.46100271 126160.65242167
#  159888.2213878  196914.30061077 143495.62495987 249533.33741153
#  212257.37104789 446929.78849201 210358.2287788  124111.57786818
#  130358.75638492 296612.07471369 183277.65775448 248733.69856138
#  239944.86623409 200462.69800828 111467.2885503  151349.27620118
#  118064.30906398 109368.23656867 183027.77061381 115715.36994168
#  198713.48802359 147351.08195046 229699.49346663 131958.03408521
#  216655.38472367 111767.1531191  212514.45321284 157346.56757725
#  161887.31851316 294912.84215714 289515.27991867 214306.44560138
#  122412.34531163 242193.85050012  78089.56158111 118514.10591718
#  274172.20948156 228350.10290702 110567.69484389 168484.33902684
#  138005.30288942 185076.84516731 262927.28815142 148750.44993821
#   83744.20598452 222002.96953401 133657.26664176 232748.1165828
#  157889.12426245 226807.99765914 135706.34119526 207309.60566263
#  270081.25539885 227107.86222794 227900.30605381 316845.73808366
#  253488.74925838 279269.90715122 173881.9012653  181628.40262606
#   92033.26403047 122462.32273976 198313.66859852 214906.17473899
#  179929.17006951 161087.67966302 111767.1531191  228300.12547888
#  187125.9197208  150149.81792596 249383.40512712 207209.65080636
#   84036.87552904 185476.66459238 152391.60716771 213007.0324699
#  175131.33696865  48210.25458129 230049.33546357 132807.65036349
#  146451.48824405  67544.32424485 207209.65080636 253231.66709344
#  125760.8329966   93032.81259315 288715.64106853 124561.37472139
#  239337.9420722  219104.27870224 267525.21153974 292114.10618164
#  239095.24995581 231048.88402625 120563.18047067 123361.91644617
#  168834.18102378 207559.4928033  185576.61944864 188225.42313974
#  125560.92328407 314846.6409583  208808.92850665 113266.47596312
#  155190.34314321 193023.2562406  112666.74682551 236696.33340538
#   66294.8885415  219054.3012741  113566.34053192  81637.95897862
#  143495.62495987 147151.17223793 164543.31722854 175338.44170547
#   87485.31807029 202511.77256177 109368.23656867 226201.07349726
#  129259.25296598 222002.96953401 214906.17473899 122262.41302723
#  195714.84233556 154148.01217668 174631.56268731 191916.55779738
#  187618.49897786 295655.30855487 116265.12165115 288515.731356
#  121062.95475201 123411.89387431 284917.35653035 131058.4403788
#  109525.36387735  84036.87552904 306607.56034048 161994.4683937
#  304701.22304711 171682.89442741 215206.03930779 208309.15422531
#  236596.37854911 118514.10591718 162886.86707584 134956.67977325
#  125960.74270914 105127.35020156 173182.21727143 162537.0250789
#  166535.21932962 130058.89181612 412495.34050773 143802.68455295
#  154347.92188921 161837.34108503 113566.34053192  86285.85979507
#  175031.38211238  -5008.51135707 189167.79925001  79089.11014378
#  154190.79458053 156889.57569977 163686.50592598 161287.58937555
#  174838.66742413 168584.29388311 124211.53272445 230998.90659811
#  229999.35803544 199120.50247294  68800.95497247 113666.29538819
#  169541.06004193 131808.10180081 257429.77105669 168641.46633552
#  114815.77623527 222552.72124348 144652.30083123 232048.43258893
#  155690.11742455 208109.24451277 166785.10647029 108168.77829346
#  292314.01589417 -16346.1925192  170183.57158339 108625.77017094
#  229749.47089477 133657.26664176 215613.05375714 132757.67293535
#  144552.34597496 264626.52070797 100729.33652578 184776.9805985
#  210408.20620693 117964.35420771 121162.90960828 241943.96335945
#  156946.74815218 122212.43559909 223202.42780922 127759.93012196
#  151149.36648864 199527.51692229 171975.56397194 308214.03306504
#  137098.51415873 208266.37182145 168934.13588004 152548.73447639
#  190874.22683084 226650.87035046 228699.94490395 244835.45916694
#  128559.5689721  160887.76995048 215655.836161    67544.32424485
#  183977.34174836 222816.9984327  125760.8329966  222002.96953401
#  230349.20003237 201812.0885679  290557.61088521 196721.58592251
#  118064.30906398 190367.25752523 140554.15172425  55506.95908884
#   88035.06977976 191074.13654338 166942.23377896 190867.03180656
#  168684.24873937 135756.31862339 204310.95997459 124611.35214952
#  262727.37843889 186576.16801132 245785.03030148 245035.36887947
#  135063.82965379 194472.60165648 150442.48747049 123162.00673364
#  208808.92850665 198970.57018854 339735.400169   176630.65981267
#  250832.75054301 174531.60783105 284367.60482088 113266.47596312
#  250040.30671714 178536.99710604 165985.46762014 334287.8605024
#  116814.87336063 231798.54544826 100829.29138205  92333.12859928
#  139654.55801784 272780.03651808 135506.43148272  73391.68333652
#  173981.85612157 111767.1531191  194465.40663221  46710.93173727
#  332038.87623638 150749.54706357 140596.9341281  251482.45710875
#  170783.300721   108368.68800599 202011.99828043 190674.31711831
#  132707.69550722 121412.79674895 161487.49908809 120563.18047067
#  253731.44137478 170233.54901153 161944.49096557 228492.84016714
#  239944.86623409 254531.08022492 244685.52688254 196914.30061077
#  196214.6166169  251782.32167755]

# %% [markdown]
# ## Оценка модели

# %% [markdown]
# После получения предсказаний нужно проверить, насколько они получились хорошими. Воспользуемся метрикой RMSE

# %%
from sklearn import metrics

# выведем корень среднеквадратической ошибки
print('RMSE = ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# RMSE =  44512.61883247343

# %%
print('MAE = ', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MAE =  28294.423558561204

# %% [markdown]
# ### Геометрический смысл

# %%
X = df[['GrLivArea']]
y = df['SalePrice']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

model = LinearRegression()

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print('RMSE = ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# RMSE =  57703.05172819449

# %%
# построим график
plt.scatter(X_test, y_test)
plt.scatter(X_test, y_test, color = 'green')
plt.plot(X_test, y_pred, color = 'red')

plt.xlabel('Above grade (ground) living area square feet')
plt.ylabel('The property\'s sale price in dollars')
# Out:
# Text(0, 0.5, "The property's sale price in dollars")

# %%
model.coef_
# Out:
# array([104.35489129])

# %%
model.intercept_
# Out:
# np.float64(22061.539749853662)

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, y_pred, color = 'red')
plt.plot(X_test, 26322 + X_test * 101, color='green')

plt.xlabel('Above grade (ground) living area square feet')
plt.ylabel('The property\'s sale price in dollars')
# Out:
# Text(0, 0.5, "The property's sale price in dollars")

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, y_pred, color = 'red')
plt.plot(X_test, 66322 + X_test * 100, color='green')

plt.xlabel('Количество комнат')
plt.ylabel('Медианная цена недвижимости')
# Out:
# Text(0, 0.5, 'Медианная цена недвижимости')
